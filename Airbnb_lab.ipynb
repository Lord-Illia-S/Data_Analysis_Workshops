# %%
import pandas as pd
import numpy as np

airbnb = pd.read_csv("data/airbnb.csv")

# %%
airbnb.head(3)
# Out:
#    Unnamed: 0  listing_id                                               name  \
# 0           0    13740704  Cozy,budget friendly, cable inc, private entra...
# 1           1    22005115              Two floor apartment near Central Park
# 2           2    21667615                  Beautiful 1BR in Brooklyn Heights
#
#     host_id host_name          neighbourhood_full            coordinates  \
# 0  20583125    Michel         Brooklyn, Flatlands  (40.63222, -73.93398)
# 1  82746113   Cecilia  Manhattan, Upper West Side  (40.78761, -73.96862)
# 2     78251    Leslie  Brooklyn, Brooklyn Heights   (40.7007, -73.99517)
#
#       room_type  price  number_of_reviews last_review  reviews_per_month  \
# 0  Private Room   45.0                 10  2018-12-12                0.7
# 1  Entire place  135.0                  1  2019-06-30                1.0
# 2  Entire place  150.0                  0         NaN                NaN
#
# ...

# %% [markdown]
# ### TO DO
#
#  -  drop first column
#  - coordinates should be ints
#  -  price should be ints ✅
#  -  different types of rooms that mean the same thing (PRIVATE ROOM/Private) ✅

# %% [markdown]
# ## Useful function
#
# ``` airbnb.info() ```
# ``` airbnb.describe() ```
# ``` airbnb.isna().sum() ```
#  ```airbnb.shape ```
# ``` airbnb['room_type'].unique() ```

# %%
airbnb['room_type'] = airbnb['room_type'].str.lower()
airbnb['room_type'].unique()
# Out:
# <StringArray>
# [        'private room',      'entire home/apt',              'private',
#           'shared room',                 'home', '   shared room      ']
# Length: 6, dtype: str

# %%
airbnb['room_type'] = airbnb['room_type'].str.strip()
airbnb['room_type'].unique()
# Out:
# <StringArray>
# ['private room', 'entire home/apt', 'private', 'shared room', 'home']
# Length: 5, dtype: str

# %%
mappings = {'private room': 'Private Room', 'private': 'Private Room', 'entire home/apt': 'Entire place', 'shared room': 'Shared room', 'home': 'Entire place'}
airbnb['room_type'] = airbnb['room_type'].replace(mappings)
airbnb['room_type'].unique()
# Out:
# <StringArray>
# ['Private Room', 'Entire place', 'Shared room']
# Length: 3, dtype: str

# %%
airbnb['price'] = airbnb['price'].str.strip('$')
airbnb['price'].unique()
# Out:
# <StringArray>
# [  '45',  '135',  '150',   '86',  '160',  '200',  '224',  '169',   '75',
#    '50',
#  ...
#   '737',  '114',  '218',  '297',  '247',  '680', '1395', '4160',  '583',
#  '5250']
# Length: 434, dtype: str

# %%
airbnb['price'] = airbnb['price'].astype('float')
airbnb['price'].unique()
# Out:
# array([  45.,  135.,  150.,   86.,  160.,  200.,  224.,  169.,   75.,
#          50.,  254.,   41.,   49.,  350.,  165.,   98.,  230.,   99.,
#         275.,   90.,   55.,  180.,  115.,  185.,  100.,   95.,   60.,
#          85.,   64.,  145.,   80.,  199.,   42.,   93.,   69.,  110.,
#         159.,   25.,  289.,  125.,  175.,   32.,  450.,  189.,   48.,
#         130.,  465.,   65.,   30.,  140.,   78.,  300.,   72.,  120.,
#         295.,  195.,  250.,  416.,   70.,   40.,  459.,   56.,  358.,
#         299.,   38.,  361.,  256., 1500.,  164.,   89.,  190.,   62.,
#         198.,   87.,   84.,   97.,   83.,   73.,  599.,   29.,   nan,
#         122.,   66.,  245.,   35.,   63.,  113.,  249.,  179.,  128.,
#         111.,   76.,  188.,  106.,  119.,  108.,  214.,  183.,  225.,
#         320.,   39.,  105.,   88.,  325.,  220.,  525.,   47.,   68.,
#          58.,  137.,  260.,  400.,  146.,   54.,  750.,  178.,   28.,
# ...

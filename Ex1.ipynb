# %% [markdown]
# # Exercise 1. - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# Check out [Occupation Exercises Video Tutorial](https://www.youtube.com/watch?v=W8AB5s-L3Rw&list=PLgJhDSE2ZLxaY_DigHeiIDC1cD09rXgJv&index=4) to watch a data scientist go through the exercises
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users and use the 'user_id' as index

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
users = pd.read_csv(url, sep='|', index_col='user_id')
# users.head()

# %% [markdown]
# ### Step 4. See the first 25 entries

# %%
# Illia
users.head(25)

# %% [markdown]
# ### Step 5. See the last 10 entries

# %%
# Illia
users.tail(10)
users.tail(10)

# %% [markdown]
# ### Step 6. What is the number of observations in the dataset?

# %%
# Illia
len(users)

# %% [markdown]
# ### Step 7. What is the number of columns in the dataset?

# %%
# Illia
len(users.columns)

# %% [markdown]
# ### Step 8. Print the name of all the columns.

# %%
# Mateusz
list(users.columns)
# Out:
# ['age', 'gender', 'occupation', 'zip_code']

# %% [markdown]
# ### Step 9. How is the dataset indexed?

# %%
# Mateusz
users.index
# Out:
# RangeIndex(start=1, stop=944, step=1, name='user_id')

# %% [markdown]
# ### Step 10. What is the data type of each column?

# %%
# Mateusz
users.dtypes
# Out:
# age           int64
# gender          str
# occupation      str
# zip_code        str
# dtype: object

# %% [markdown]
# ### Step 11. Print only the occupation column

# %%
# Mateusz
users['occupation']
# Out:
# user_id
# 1         technician
# 2              other
# 3             writer
# 4         technician
# 5              other
#            ...
# 939          student
# 940    administrator
# 941          student
# 942        librarian
# 943          student
# Name: occupation, Length: 943, dtype: str

# %% [markdown]
# ### Step 12. How many different occupations are in this dataset?

# %%
users.occupation.drop_duplicates().count()

# %% [markdown]
# ### Step 13. What is the most frequent occupation?

# %%
users.occupation.value_counts().head(1)

# %% [markdown]
# ### Step 14. Summarize the DataFrame.

# %%
users.describe()

# %% [markdown]
# ### Step 15. Summarize all the columns

# %%
users.describe(include="all")

# %% [markdown]
# ### Step 16. Summarize only the occupation column

# %%
# Kuba
users.agg({'occupation': 'sum'})

# %% [markdown]
# ### Step 17. What is the mean age of users?

# %%
# Kuba
users.agg({'age': 'mean'})

# %% [markdown]
# ### Step 18. What is the age with least occurrence?

# %%
# Kuba
users['age'].value_counts().sort_values().head(5)

# %% [markdown]
# # Project: Occupation Exercise
#
# ## Data Import
# Loaded dataset from GitHub using `pd.read_csv()`.
#
# ## Data Cleaning & Transformation
# - Filtered for specific regions using `.query()`.
# - Reshaped data from wide to long format using `.melt()`.
# - Created new features like `mpg_per_cylinder` via `.assign()`.
#
# ## Statistical Summary
# - Grouped by `continent` to calculate mean consumption across all metrics using `.groupby().mean()`.
# - Identified least frequent occurrences using `value_counts().idxmin()`.
#
# ## Key Findings
# - Europe shows the highest average wine consumption.
# - [Insert other specific observations here].

# %% [markdown]
# # Project: Workplace Exercise
#
# ## Kuba 30.03.2026 - 7:51
#
# ## Data Import
# Loaded dataset from https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user
#
# ## Ex 16 & 17
# Completed using pandas agg
#
#
# ## Ex 18
# Used head(5) becasue only these values appear Once, the rest twice
